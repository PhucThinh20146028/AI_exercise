# %% [markdown]
# <a href="https://colab.research.google.com/github/PhucThinh20146028/AI_exercise/blob/main/AI_W3_18_02_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#CREATE A DATAFRAME
#load library
import pandas as pd
#create dataframe
dataframe = pd.DataFrame()
#add column
dataframe['Name'] = ['Lemon','Apple','Banana']
dataframe['Price'] = [5,8,7]
dataframe['License'] = [False,True,True]
#show data
dataframe
# Out:
#      Name  Price  License
# 0   Lemon      5    False
# 1   Apple      8     True
# 2  Banana      7     True

# %%
dataframe.shape
# Out:
# (3, 3)

# %%
df=dataframe
df.info()
#bool la kieu logic, int64 la kieu so rieng, object la kieu string
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     3 non-null      object
#  1   Price    3 non-null      int64
#  2   License  3 non-null      bool
# dtypes: bool(1), int64(1), object(1)
# memory usage: 179.0+ bytes

# %%
# print column name
list(df.columns)
# Out:
# ['Name', 'Price', 'License']

# %%
df.describe()
#mean la stb
#std la do lech chuan
# Out:
#           Price
# count  3.000000
# mean   6.666667
# std    1.527525
# min    5.000000
# 25%    6.000000
# 50%    7.000000
# 75%    7.500000
# max    8.000000

# %%
#loc iloc
df.loc[(df.Price == 5)]
# Out:
#     Name  Price  License
# 0  Lemon      5    False

# %%
df.loc[(df.Price == 5)|(df.Name == 'Banana')]
# Out:
#      Name  Price  License
# 0   Lemon      5    False
# 2  Banana      7     True

# %%
df.loc[(df.Price == 5)|(df.Name == 'Banana'),('Name','Price')]
# Out:
#      Name  Price
# 0   Lemon      5
# 2  Banana      7

# %%
df.iloc[2]
type(df.iloc[2])
# Out:
# pandas.core.series.Series

# %%
df.iloc[[2]]
#phai co 2 [] de in ra dang bang
# Out:
#      Name  Price  License
# 2  Banana      7     True

# %%
df.iloc[0:2]
# Out:
#     Name  Price  License
# 0  Lemon      5    False
# 1  Apple      8     True

# %%
df.iloc[0:2,0:-1]
# Out:
#     Name  Price
# 0  Lemon      5
# 1  Apple      8

# %%
df.iloc[0:2,-1]
# Out:
# 0    False
# 1     True
# Name: License, dtype: bool

# %%
sum = df.Price.sum()
print(sum)
# Out:
# 20

# %%
max = df.Price.max()
print(max)
# Out:
# 8

# %%
count = df['Price'].count()
print(count)
# Out:
# 3

# %%
#create row data
new = pd.Series(['Orange',10,True], index=['Name','Price','License'])
#append row
dataframe.append(new,ignore_index = True)
#(ten,)
# Out:
#      Name  Price  License Location
# 0   Lemon      5    False      USA
# 1   Apple      8     True       VN
# 2  Banana      7     True      SIN
# 3  Orange     10     True      NaN

# %%
#append a column
dataframe['Location'] = ['USA','VN','SIN']
dataframe
# Out:
#      Name  Price  License Location
# 0   Lemon      5    False      USA
# 1   Apple      8     True       VN
# 2  Banana      7     True      SIN

# %%
#delete a row
dataframe.drop(1,axis=0).head(10)
#index 1 la so lieu hang (can phai cung cap so lieu), axis = 0 la hang, axis = 1 la cot
# Out:
#      Name  Price  License Location
# 0   Lemon      5    False      USA
# 2  Banana      7     True      SIN

# %%
#delete a column
dataframe.drop('Location',axis=1).head()
#index la 'Location'
#neu head ko co tham so, mac dinh hien 5 hang dau
# Out:
#      Name  Price  License
# 0   Lemon      5    False
# 1   Apple      8     True
# 2  Banana      7     True

# %%
#replace
dataframe['Price'].replace(5,7).head()
# Out:
# 0    7
# 1    8
# 2    7
# Name: Price, dtype: int64

# %%
#rename columns (thay ten Price thanh Cost)
dataframe.rename(columns={'Price':'Cost'}).head()
# Out:
#      Name  Cost  License Location
# 0   Lemon     5    False      USA
# 1   Apple     8     True       VN
# 2  Banana     7     True      SIN

# %%
#2 Knowing Data
# load library
import pandas as pd
# create url
url = 'http://winterolympicsmedals.com/medals.csv'
# load data
dataframe = pd.read_csv(url)
# show data
dataframe.head()
# Out:
#    Year      City       Sport      Discipline  NOC       Event Event gender  \
# 0  1924  Chamonix     Skating  Figure skating  AUT  individual            M
# 1  1924  Chamonix     Skating  Figure skating  AUT  individual            W
# 2  1924  Chamonix     Skating  Figure skating  AUT       pairs            X
# 3  1924  Chamonix   Bobsleigh       Bobsleigh  BEL    four-man            M
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  CAN  ice hockey            M
#
#     Medal
# 0  Silver
# 1    Gold
# 2    Gold
# 3  Bronze
# 4    Gold

# %%
dt = dataframe
dt.shape
# Out:
# (2311, 8)

# %%
dt.iloc[0:10]
 # ~[:10]
# Out:
#    Year      City       Sport      Discipline  NOC            Event  \
# 0  1924  Chamonix     Skating  Figure skating  AUT       individual
# 1  1924  Chamonix     Skating  Figure skating  AUT       individual
# 2  1924  Chamonix     Skating  Figure skating  AUT            pairs
# 3  1924  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# 5  1924  Chamonix    Biathlon        Biathlon  FIN  military patrol
# 6  1924  Chamonix     Skating  Figure skating  FIN            pairs
# 7  1924  Chamonix     Skating   Speed skating  FIN           10000m
# 8  1924  Chamonix     Skating   Speed skating  FIN           10000m
# 9  1924  Chamonix     Skating   Speed skating  FIN            1500m
#
#   Event gender   Medal
# 0            M  Silver
# 1            W    Gold
# 2            X    Gold
# 3            M  Bronze
# 4            M    Gold
# 5            M  Silver
# 6            X  Silver
# 7            M    Gold
# ...

# %%
dt.iloc[[200,]]
# Out:
#      Year        City   Sport       Discipline  NOC       Event Event gender  \
# 200  1948  St. Moritz  Skiing  Nordic Combined  FIN  individual            M
#
#     Medal
# 200  Gold

# %%
dt = dt.set_index(dt['NOC'])
dt.loc['GER']
# Out:
#      Year                    City       Sport       Discipline  NOC  \
# NOC
# GER  1928              St. Moritz   Bobsleigh        Bobsleigh  GER
# GER  1932             Lake Placid   Bobsleigh        Bobsleigh  GER
# GER  1932             Lake Placid  Ice Hockey       Ice Hockey  GER
# GER  1936  Garmisch-Partenkirchen     Skating   Figure skating  GER
# GER  1936  Garmisch-Partenkirchen     Skating   Figure skating  GER
# ..    ...                     ...         ...              ...  ...
# GER  2006                   Turin      Skiing  Cross Country S  GER
# GER  2006                   Turin      Skiing  Nordic Combined  GER
# GER  2006                   Turin      Skiing  Nordic Combined  GER
# GER  2006                   Turin      Skiing  Nordic Combined  GER
# GER  2006                   Turin      Skiing        Snowboard  GER
#
#                      Event Event gender   Medal
# NOC
# GER               five-man            M  Bronze
# ...

# %%
dt.loc['USA']
# Out:
#      Year        City       Sport      Discipline  NOC                 Event  \
# NOC
# USA  1924    Chamonix  Ice Hockey      Ice Hockey  USA            ice hockey
# USA  1924    Chamonix     Skating  Figure skating  USA            individual
# USA  1924    Chamonix     Skating   Speed skating  USA                  500m
# USA  1924    Chamonix      Skiing     Ski Jumping  USA  K90 individual (70m)
# USA  1928  St. Moritz   Bobsleigh       Bobsleigh  USA              five-man
# ..    ...         ...         ...             ...  ...                   ...
# USA  2006       Turin      Skiing       Snowboard  USA             Half-pipe
# USA  2006       Turin      Skiing       Snowboard  USA             Half-pipe
# USA  2006       Turin      Skiing       Snowboard  USA             Half-pipe
# USA  2006       Turin      Skiing       Snowboard  USA       Snowboard Cross
# USA  2006       Turin      Skiing       Snowboard  USA       Snowboard Cross
#
#     Event gender   Medal
# NOC
# ...

# %%
dt[dt['NOC']=='CAN'].head(10)
# Out:
#      Year                    City       Sport      Discipline  NOC  \
# NOC
# CAN  1924                Chamonix  Ice Hockey      Ice Hockey  CAN
# CAN  1928              St. Moritz  Ice Hockey      Ice Hockey  CAN
# CAN  1932             Lake Placid  Ice Hockey      Ice Hockey  CAN
# CAN  1932             Lake Placid     Skating  Figure skating  CAN
# CAN  1932             Lake Placid     Skating   Speed skating  CAN
# CAN  1932             Lake Placid     Skating   Speed skating  CAN
# CAN  1932             Lake Placid     Skating   Speed skating  CAN
# CAN  1932             Lake Placid     Skating   Speed skating  CAN
# CAN  1932             Lake Placid     Skating   Speed skating  CAN
# CAN  1936  Garmisch-Partenkirchen  Ice Hockey      Ice Hockey  CAN
#
#           Event Event gender   Medal
# NOC
# CAN  ice hockey            M    Gold
# CAN  ice hockey            M    Gold
# CAN  ice hockey            M    Gold
# CAN  individual            M  Bronze
# ...

# %%
#yt: pandas, dataframe,codemy,freecodecamp
#web: panda,w3s
#ggsearch: pandas.cheapsheet

# %%
dt[(dt['Year']>=1990)&(dt['Year']<=2006) & (dt['NOC']=='USA')&(dt['Event gender']=='W')&(dt['Medal']=='Gold')].head(10)
#moi dieu kien de trong () & ()|()
# Out:
#      Year         City       Sport      Discipline  NOC       Event  \
# NOC
# USA  1992  Albertville     Skating  Figure skating  USA  individual
# USA  1992  Albertville     Skating  Short Track S.  USA        500m
# USA  1992  Albertville     Skating   Speed skating  USA       1000m
# USA  1992  Albertville     Skating   Speed skating  USA        500m
# USA  1992  Albertville      Skiing  Freestyle Ski.  USA      moguls
# USA  1994  Lillehammer     Skating  Short Track S.  USA        500m
# USA  1994  Lillehammer     Skating   Speed skating  USA       1000m
# USA  1994  Lillehammer     Skating   Speed skating  USA        500m
# USA  1994  Lillehammer      Skiing   Alpine Skiing  USA     super-G
# USA  1998       Nagano  Ice Hockey      Ice Hockey  USA  ice hockey
#
#     Event gender Medal
# NOC
# USA            W  Gold
# USA            W  Gold
# USA            W  Gold
# USA            W  Gold
# USA            W  Gold
# USA            W  Gold
# USA            W  Gold
# ...

# %%
dt['NOC'].value_counts()
# Out:
# NOR    280
# USA    216
# URS    194
# AUT    185
# GER    158
# FIN    151
# CAN    119
# SUI    118
# SWE    118
# GDR    110
# ITA    101
# FRA     83
# NED     78
# RUS     76
# FRG     41
# CHN     33
# JPN     32
# KOR     31
# TCH     25
# EUN     23
# GBR     21
# EUA     19
# CZE     10
# LIE      9
# POL      8
# CRO      7
# BUL      6
# EST      6
# AUS      6
# BLR      6
# HUN      6
# UKR      5
# BEL      5
# KAZ      5
# YUG      4
# SLO      4
# ESP      2
# PRK      2
# LUX      2
# LAT      1
# ROU      1
# DEN      1
# UZB      1
# NZL      1
# SVK      1
# Name: NOC, dtype: int64

# %%
dt.count()
# Out:
# Year            2311
# City            2311
# Sport           2311
# Discipline      2311
# NOC             2311
# Event           2311
# Event gender    2311
# Medal           2311
# dtype: int64

# %%
dt['NOC'].count()
# Out:
# 2311

# %%
dt['NOC'].unique()
# Out:
# array(['AUT', 'BEL', 'CAN', 'FIN', 'FRA', 'GBR', 'NOR', 'SUI', 'SWE',
#        'USA', 'GER', 'TCH', 'HUN', 'ITA', 'FRG', 'NED', 'EUA', 'JPN',
#        'POL', 'URS', 'PRK', 'GDR', 'ROU', 'ESP', 'LIE', 'BUL', 'YUG',
#        'CHN', 'EUN', 'KOR', 'LUX', 'NZL', 'AUS', 'BLR', 'KAZ', 'RUS',
#        'SLO', 'UKR', 'UZB', 'CZE', 'DEN', 'CRO', 'EST', 'LAT', 'SVK'],
#       dtype=object)

# %%
# load library
import pandas as pd
# load data
train_data = pd.read_csv('/Vehicle_Insurance.csv')
train_data.head(10)
# show data
#dataframe.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
# 5   6  Female   24                1         33.0                   0
# 6   7    Male   23                1         11.0                   0
# 7   8  Female   56                1         28.0                   0
# 8   9  Female   24                1          3.0                   1
# 9  10  Female   32                1          6.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# ...
