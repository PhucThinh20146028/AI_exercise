# %% [markdown]
# <a href="https://colab.research.google.com/github/PhucThinh20146028/AI_exercise/blob/main/Machinelearning_w7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (1.4.4)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.9/dist-packages (from pandas) (1.22.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas) (1.15.0)

# %%
#xac dinh moi quan he y=f(x) hoi quy
import numpy as np
import pandas as pd
url = 'https://raw.githubusercontent.com/htphuc2110/File-/main/mtcars.csv'
data = pd.read_csv(url)
data.head()
# Out:
#           Unnamed: 0   mpg   disp   hp     wt
# 0          Mazda RX4  21.0  160.0  110  2.620
# 1      Mazda RX4 Wag  21.0  160.0  110  2.875
# 2         Datsun 710  22.8  108.0   93  2.320
# 3     Hornet 4 Drive  21.4  258.0  110  3.215
# 4  Hornet Sportabout  18.7  360.0  175  3.440

# %%
import seaborn as sns
import matplotlib.pyplot as plt

data.hist()
plt.show()

# %%
correlation = data.corr()
print(correlation)

sns.pairplot(data)


#am la ti le nghich
#duong la ti le thuan
# Out:
#            mpg      disp        hp        wt
# mpg   1.000000 -0.847551 -0.776168 -0.867659
# disp -0.847551  1.000000  0.790949  0.887980
# hp   -0.776168  0.790949  1.000000  0.658748
# wt   -0.867659  0.887980  0.658748  1.000000

# %%
sns.heatmap(correlation,annot=True)
# Out:
# <Axes: >

# %%
data.plot(kind = 'scatter', x = 'wt', y = 'mpg', figsize = (9,9), color = 'black')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='wt', ylabel='mpg'>

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()

 #fit la ham train de day gi do
model.fit(X = pd.DataFrame(data['wt']), y = data['mpg'])
print('Gia tri Intercept la: ', model.intercept_)
print('Gia tri Coeffient la: ', model.coef_)
model.score(X = pd.DataFrame(data['wt']), y = data['mpg'])
# Out:
# Gia tri Intercept la:  37.28512616734204
# Gia tri Coeffient la:  [-5.34447157]
# 0.7528327936582646

# %%
data.plot(kind = 'scatter', x = 'wt', y = 'mpg', figsize = (9,9), color = 'black')
y_pred = model.predict(X = pd.DataFrame(data['wt']))
plt.plot(data['wt'], y_pred,color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['wt'],data['wt']**2]).T

y = data['mpg']

model.fit(X,y = data['mpg'])
print('He so Intercept la: ', model.intercept_)

print('He so Coeffient la: ', model.coef_)
print('Do chinh xac cua mo hinh la: ', model.score(X,y))
# Out:
# He so Intercept la:  49.93081094945181
# He so Coeffient la:  [-13.38033708   1.17108689]
# Do chinh xac cua mo hinh la:  0.8190613581384094

# %%
range = np.arange(1.5,5.5,0.1)
X_range = pd.DataFrame([range, range**2]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'wt', y = 'mpg', figsize = (9,9), color = 'black', xlim = (0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['wt'],data['wt']**2,data['wt']**3]).T

y = data['mpg']

model.fit(X,y = data['mpg'])
print('He so Intercept la: ', model.intercept_)
print('He so Coeffient la: ', model.coef_)
print('Do chinh xac cua mo hinh la: ', model.score(X,y))

range = np.arange(1.5,5.5,0.1)
X_range = pd.DataFrame([range, range**2, range**3]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'wt', y = 'mpg', figsize = (9,9), color = 'black', xlim = (0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# He so Intercept la:  48.40369622795221
# He so Coeffient la:  [-11.82597602   0.68937919   0.04593618]
# Do chinh xac cua mo hinh la:  0.8191284628478992
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['wt'],data['wt']**2,data['wt']**3,data['wt']**4]).T

y = data['mpg']

model.fit(X,y = data['mpg'])
print('He so Intercept la: ', model.intercept_)
print('He so Coeffient la: ', model.coef_)
print('Do chinh xac cua mo hinh la: ', model.score(X,y))

range = np.arange(1.5,5.5,0.1)
X_range = pd.DataFrame([range, range**2, range**3, range**4]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'wt', y = 'mpg', figsize = (9,9), color = 'black', xlim = (0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# He so Intercept la:  14.455833054796258
# He so Coeffient la:  [ 36.61945631 -23.70175729   5.20042113  -0.38627878]
# Do chinh xac cua mo hinh la:  0.8219709873435187
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['wt'],data['wt']**2,data['wt']**3,data['wt']**4,data['wt']**5]).T

y = data['mpg']

model.fit(X,y = data['mpg'])
print('He so Intercept la: ', model.intercept_)
print('He so Coeffient la: ', model.coef_)
print('Do chinh xac cua mo hinh la: ', model.score(X,y))

range = np.arange(1.5,5.5,0.1)
X_range = pd.DataFrame([range, range**2, range**3, range**4, range**5]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'wt', y = 'mpg', figsize = (9,9), color = 'black', xlim = (0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# He so Intercept la:  -87.71816314301019
# He so Coeffient la:  [ 218.88967608 -147.77842682   45.60934841   -6.70138798    0.37968337]
# Do chinh xac cua mo hinh la:  0.8251088272653132
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['wt'],data['wt']**2,data['wt']**3,data['wt']**4,data['wt']**5,data['wt']**6]).T

y = data['mpg']

model.fit(X,y = data['mpg'])
print('He so Intercept la: ', model.intercept_)
print('He so Coeffient la: ', model.coef_)
print('Do chinh xac cua mo hinh la: ', model.score(X,y))

range = np.arange(1.5,5.5,0.1)
X_range = pd.DataFrame([range, range**2, range**3, range**4, range**5, range**6]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'wt', y = 'mpg', figsize = (9,9), color = 'black', xlim = (0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# He so Intercept la:  -580.1180291191426
# He so Coeffient la:  [ 1.25251793e+03 -1.01544961e+03  4.19153811e+02 -9.38894251e+01
#   1.08661013e+01 -5.09042883e-01]
# Do chinh xac cua mo hinh la:  0.8322482465599783
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['wt'],data['wt']**2,data['wt']**3,data['wt']**4,data['wt']**5,data['wt']**6,data['wt']**7]).T

y = data['mpg']

model.fit(X,y = data['mpg'])
print('He so Intercept la: ', model.intercept_)
print('He so Coeffient la: ', model.coef_)
print('Do chinh xac cua mo hinh la: ', model.score(X,y))

range = np.arange(1.5,5.5,0.1)
X_range = pd.DataFrame([range, range**2, range**3, range**4, range**5, range**6, range**7]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'wt', y = 'mpg', figsize = (9,9), color = 'black', xlim = (0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# He so Intercept la:  -2387.286256135588
# He so Coeffient la:  [ 5.71347281e+03 -5.57680321e+03  2.92547757e+03 -8.93984147e+02
#   1.59440329e+02 -1.53893379e+01  6.21028572e-01]
# Do chinh xac cua mo hinh la:  0.8380739929060077
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['wt'],data['wt']**2,data['wt']**3,data['wt']**4,data['wt']**5,data['wt']**6,data['wt']**7,data['wt']**8]).T

y = data['mpg']

model.fit(X,y = data['mpg'])
print('He so Intercept la: ', model.intercept_)
print('He so Coeffient la: ', model.coef_)
print('Do chinh xac cua mo hinh la: ', model.score(X,y))

range = np.arange(1.5,5.5,0.1)
X_range = pd.DataFrame([range, range**2, range**3, range**4, range**5, range**6, range**7, range**8]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'wt', y = 'mpg', figsize = (9,9), color = 'black', xlim = (0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# He so Intercept la:  1582.7973359661294
# He so Coeffient la:  [-5.64544414e+03  8.25196062e+03 -6.43425547e+03  2.96002820e+03
#  -8.29805697e+02  1.39294521e+02 -1.28609866e+01  5.01914523e-01]
# Do chinh xac cua mo hinh la:  0.8402829929877587
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['wt'],data['wt']**2,data['wt']**3,data['wt']**4,data['wt']**5,data['wt']**6,data['wt']**7,data['wt']**8,data['wt']**9]).T

y = data['mpg']

model.fit(X,y = data['mpg'])
print('He so Intercept la: ', model.intercept_)
print('He so Coeffient la: ', model.coef_)
print('Do chinh xac cua mo hinh la: ', model.score(X,y))

range = np.arange(1.5,5.5,0.1)
X_range = pd.DataFrame([range, range**2, range**3, range**4, range**5, range**6, range**7, range**8, range**9]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'wt', y = 'mpg', figsize = (9,9), color = 'black', xlim = (0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# He so Intercept la:  38889.610890257565
# He so Coeffient la:  [-1.25317627e+05  1.74784059e+05 -1.38423294e+05  6.86522656e+04
#  -2.21343938e+04  4.64432999e+03 -6.12230173e+02  4.60606389e+01
#  -1.50849985e+00]
# Do chinh xac cua mo hinh la:  0.8646786785489688
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['wt'],data['wt']**2,data['wt']**3,data['wt']**4,data['wt']**5,data['wt']**6,data['wt']**7,data['wt']**8,data['wt']**9,data['wt']**10]).T

y = data['mpg']

model.fit(X,y = data['mpg'])
print('He so Intercept la: ', model.intercept_)
print('He so Coeffient la: ', model.coef_)
print('Do chinh xac cua mo hinh la: ', model.score(X,y))

range = np.arange(1.5,5.5,0.1)
X_range = pd.DataFrame([range, range**2, range**3, range**4, range**5, range**6, range**7, range**8, range**9, range**10]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'wt', y = 'mpg', figsize = (9,9), color = 'black', xlim = (0,7))
plt.plot(range,y_pred,color='blue')

#bac 3 la 82
#bac 4 la
# Out:
# He so Intercept la:  -14921.11995188375
# He so Coeffient la:  [ 6.45813558e+04 -1.20086131e+05  1.26931928e+05 -8.46598454e+04
#   3.73155199e+04 -1.10334755e+04  2.16590404e+03 -2.70730544e+02
#   1.94974162e+01 -6.15515436e-01]
# Do chinh xac cua mo hinh la:  0.8702106571479111
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['wt'],data['wt']**2,data['wt']**3,data['wt']**4,data['wt']**5,data['wt']**6,data['wt']**7,data['wt']**8,data['wt']**9,data['wt']**10,data['wt']**11]).T

y = data['mpg']

model.fit(X,y = data['mpg'])
print('He so Intercept la: ', model.intercept_)
print('He so Coeffient la: ', model.coef_)
print('Do chinh xac cua mo hinh la: ', model.score(X,y))

range = np.arange(1.5,5.5,0.1)
X_range = pd.DataFrame([range, range**2, range**3, range**4, range**5, range**6, range**7, range**8, range**9, range**10,range**11]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'wt', y = 'mpg', figsize = (9,9), color = 'black', xlim = (0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# He so Intercept la:  -231415.3012044087
# He so Coeffient la:  [ 9.15190229e+05 -1.60853068e+06  1.65815938e+06 -1.11378394e+06
#   5.11894008e+05 -1.64309153e+05  3.68501885e+04 -5.66220383e+03
#   5.68057758e+02 -3.35128769e+01  8.81444412e-01]
# Do chinh xac cua mo hinh la:  0.8757492427094143
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['wt'],data['wt']**2,data['wt']**3,data['wt']**4,data['wt']**5,data['wt']**6,data['wt']**7,data['wt']**8,data['wt']**9,data['wt']**10,data['wt']**11,data['wt']**12]).T

y = data['mpg']

model.fit(X,y = data['mpg'])
print('He so Intercept la: ', model.intercept_)
print('He so Coeffient la: ', model.coef_)
print('Do chinh xac cua mo hinh la: ', model.score(X,y))

range = np.arange(1.5,5.5,0.1)
X_range = pd.DataFrame([range, range**2, range**3, range**4, range**5, range**6, range**7, range**8, range**9, range**10,range**11,range**12]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'wt', y = 'mpg', figsize = (9,9), color = 'black', xlim = (0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# He so Intercept la:  -65800.54863555655
# He so Coeffient la:  [ 1.90993674e+05 -1.83461497e+05 -1.04603728e+04  1.81092639e+05
#  -1.89777363e+05  1.07986871e+05 -3.94160694e+04  9.64335877e+03
#  -1.57898878e+03  1.66394776e+02 -1.02152551e+01  2.77831756e-01]
# Do chinh xac cua mo hinh la:  0.877313187530598
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['wt'],data['wt']**2,data['wt']**3,data['wt']**4,data['wt']**5,data['wt']**6,data['wt']**7,data['wt']**8,data['wt']**9,data['wt']**10,data['wt']**11,data['wt']**12,data['wt']**13]).T

y = data['mpg']

model.fit(X,y = data['mpg'])
print('He so Intercept la: ', model.intercept_)
print('He so Coeffient la: ', model.coef_)
print('Do chinh xac cua mo hinh la: ', model.score(X,y))

range = np.arange(1.5,5.5,0.1)
X_range = pd.DataFrame([range, range**2, range**3, range**4, range**5, range**6, range**7, range**8, range**9, range**10,range**11,range**12,range**13]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'wt', y = 'mpg', figsize = (9,9), color = 'black', xlim = (0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# He so Intercept la:  -17924.755432355403
# He so Coeffient la:  [ 3.71870708e+04 -1.11935404e+04 -2.73527312e+04  1.74923731e+04
#   1.94582373e+04 -3.37840508e+04  2.30525606e+04 -9.32336224e+03
#   2.44117997e+03 -4.19739539e+02  4.59106860e+01 -2.90313644e+00
#   8.08994091e-02]
# Do chinh xac cua mo hinh la:  0.8784498973119335
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['wt'],data['wt']**2,data['wt']**3,data['wt']**4,data['wt']**5,data['wt']**6,data['wt']**7,data['wt']**8,data['wt']**9,data['wt']**10,data['wt']**11,data['wt']**12,data['wt']**13,data['wt']**14]).T

y = data['mpg']

model.fit(X,y = data['mpg'])
print('He so Intercept la: ', model.intercept_)
print('He so Coeffient la: ', model.coef_)
print('Do chinh xac cua mo hinh la: ', model.score(X,y))

range = np.arange(1.5,5.5,0.1)
X_range = pd.DataFrame([range, range**2, range**3, range**4, range**5, range**6, range**7, range**8, range**9, range**10,range**11,range**12,range**13,range**14]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'wt', y = 'mpg', figsize = (9,9), color = 'black', xlim = (0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# He so Intercept la:  -4739.037068068236
# He so Coeffient la:  [ 6.82294357e+03  1.71186897e+03 -4.96439227e+03 -2.63872627e+03
#   4.80831363e+03  1.77759415e+03 -6.21675245e+03  4.96758258e+03
#  -2.18465110e+03  6.04127905e+02 -1.08023874e+02  1.21722270e+01
#  -7.88002041e-01  2.23827146e-02]
# Do chinh xac cua mo hinh la:  0.8790911067088647
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['wt'],data['wt']**2,data['wt']**3,data['wt']**4,data['wt']**5,data['wt']**6,data['wt']**7,data['wt']**8,data['wt']**9,data['wt']**10,data['wt']**11,data['wt']**12,data['wt']**13,data['wt']**14,data['wt']**15]).T

y = data['mpg']

model.fit(X,y = data['mpg'])
print('He so Intercept la: ', model.intercept_)
print('He so Coeffient la: ', model.coef_)
print('Do chinh xac cua mo hinh la: ', model.score(X,y))

range = np.arange(1.5,5.5,0.1)
X_range = pd.DataFrame([range, range**2, range**3, range**4, range**5, range**6, range**7, range**8, range**9, range**10,range**11,range**12,range**13,range**14,range**15]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'wt', y = 'mpg', figsize = (9,9), color = 'black', xlim = (0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# He so Intercept la:  -1183.775900530815
# He so Coeffient la:  [ 1.15482832e+03  8.26985531e+02 -3.77299068e+02 -9.90227356e+02
#  -8.54738725e+01  1.01497570e+03  5.84542984e+01 -1.14654333e+03
#   1.05398762e+03 -4.97390219e+02  1.43996618e+02 -2.66141482e+01
#   3.07575388e+00 -2.03158530e-01  5.86600122e-03]
# Do chinh xac cua mo hinh la:  0.8793156609915943
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
url = 'https://raw.githubusercontent.com/htphuc2110/File-/main/50_Startups.csv'
data = pd.read_csv(url)
data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
import seaborn as sns
import matplotlib.pyplot as plt

data.hist()
plt.show()

# %%
correlation = data.corr()
print(correlation)
# Out:
#                  R&D Spend  Administration  Marketing Spend    Profit
# R&D Spend         1.000000        0.241955         0.724248  0.972900
# Administration    0.241955        1.000000        -0.032154  0.200717
# Marketing Spend   0.724248       -0.032154         1.000000  0.747766
# Profit            0.972900        0.200717         0.747766  1.000000

# %%
sns.pairplot(data)

# %%
sns.heatmap(correlation,annot=True)
# Out:
# <Axes: >

# %%
# x la R&D Spend, y la Profit
from sklearn import linear_model
model = linear_model.LinearRegression()

 #Y la Profit
model.fit(X = pd.DataFrame(data['R&D Spend']), y = data['Profit'])
print('Gia tri Intercept la: ', model.intercept_)
print('Gia tri Coeffient la: ', model.coef_)
model.score(X = pd.DataFrame(data['R&D Spend']), y = data['Profit'])
# Out:
# Gia tri Intercept la:  49032.89914125215
# Gia tri Coeffient la:  [0.85429137]
# 0.9465353160804393

# %%
data.plot(kind = 'scatter', x = 'R&D Spend', y = 'Profit', figsize = (9,9), color = 'black')
y_pred = model.predict(X = pd.DataFrame(data['R&D Spend']))
plt.plot(data['R&D Spend'], y_pred,color='red')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['R&D Spend'],data['R&D Spend']**2]).T

y = data['Profit']

model.fit(X,y = data['Profit'])
print('He so Intercept la: ', model.intercept_)
print('He so Coeffient la: ', model.coef_)
print('Do chinh xac cua mo hinh la: ', model.score(X,y))

range = np.arange(5000,200000,1000)
X_range = pd.DataFrame([range, range**2]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'R&D Spend', y = 'Profit', figsize = (9,9), color = 'black', xlim = (0.7))
plt.plot(range,y_pred,color='red')
# Out:
# He so Intercept la:  48128.14916956878
# He so Coeffient la:  [ 8.90147291e-01 -2.31821806e-07]
# Do chinh xac cua mo hinh la:  0.946703652909133
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['R&D Spend'],data['R&D Spend']**2,data['R&D Spend']**3]).T

y = data['Profit']

model.fit(X,y = data['Profit'])
print('He so Intercept la: ', model.intercept_)
print('He so Coeffient la: ', model.coef_)
print('Do chinh xac cua mo hinh la: ', model.score(X,y))

range = np.arange(50000,200000,1000)
X_range = pd.DataFrame([range, range**2, range**3]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'R&D Spend', y = 'Profit', figsize = (9,9), color = 'black', xlim = (0.7))
plt.plot(range,y_pred,color='red')
# Out:
# He so Intercept la:  43108.76756818297
# He so Coeffient la:  [ 1.40072682e+00 -8.82403324e-06  3.64774030e-11]
# Do chinh xac cua mo hinh la:  0.9540709421464032
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['R&D Spend'],data['R&D Spend']**2,data['R&D Spend']**3,data['R&D Spend']**4,data['R&D Spend']**5,data['R&D Spend']**6,data['R&D Spend']**7,data['R&D Spend']**8,data['R&D Spend']**9,data['R&D Spend']**10,data['R&D Spend']**11,data['R&D Spend']**12,data['R&D Spend']**13,data['R&D Spend']**14,data['R&D Spend']**15]).T

y = data['Profit']

model.fit(X,y = data['Profit'])
print('He so Intercept la: ', model.intercept_)
print('He so Coeffient la: ', model.coef_)
print('Do chinh xac cua mo hinh la: ', model.score(X,y))

range = np.arange(50000,200000,1000)
X_range = pd.DataFrame([range, range**2, range**3, range**4, range**5, range**6, range**7, range**8, range**9, range**10,range**11,range**12,range**13,range**14,range**15]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'R&D Spend', y = 'Profit', figsize = (9,9), color = 'black', xlim = (0.7))
plt.plot(range,y_pred,color='red')
# Out:
# He so Intercept la:  95288.78232301159
# He so Coeffient la:  [ 2.81983321e-121  1.13624599e-064  2.22720596e-071  6.90893484e-077
#   1.37125460e-100  1.04826599e-095  1.19522800e-090  1.31550977e-085
#   1.38214312e-080  1.35934814e-075  1.20715831e-070  8.96354556e-066
#   4.45216336e-061 -5.41727505e-066  1.65347961e-071]
# Do chinh xac cua mo hinh la:  0.59760141010809
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
import numpy as np
import pandas as pd
url = 'https://raw.githubusercontent.com/htphuc2110/File-/main/mtcars.csv'
data = pd.read_csv(url)
data.head(10)
# Out:
#           Unnamed: 0   mpg   disp   hp     wt
# 0          Mazda RX4  21.0  160.0  110  2.620
# 1      Mazda RX4 Wag  21.0  160.0  110  2.875
# 2         Datsun 710  22.8  108.0   93  2.320
# 3     Hornet 4 Drive  21.4  258.0  110  3.215
# 4  Hornet Sportabout  18.7  360.0  175  3.440
# 5            Valiant  18.1  225.0  105  3.460
# 6         Duster 360  14.3  360.0  245  3.570
# 7          Merc 240D  24.4  146.7   62  3.190
# 8           Merc 230  22.8  140.8   95  3.150
# 9           Merc 280  19.2  167.6  123  3.440

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data.hist()
plt.show()

# %%
correlation = data.corr()
print(correlation)

sns.pairplot(data)
# Out:
#            mpg      disp        hp        wt
# mpg   1.000000 -0.847551 -0.776168 -0.867659
# disp -0.847551  1.000000  0.790949  0.887980
# hp   -0.776168  0.790949  1.000000  0.658748
# wt   -0.867659  0.887980  0.658748  1.000000

# %%
sns.heatmap(correlation,annot=True)
# Out:
# <Axes: >

# %%
data.plot(kind = 'scatter', x = 'wt', y = 'mpg', figsize = (9,9), color = 'black')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='wt', ylabel='mpg'>

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['wt'],data['wt']**2,data['wt']**3,data['wt']**4,data['wt']**5,data['wt']**6,data['wt']**7,data['wt']**8,data['wt']**9,data['wt']**10]).T

y = data['mpg']

model.fit(X,y = data['mpg'])
print('He so Intercept la: ', model.intercept_)
print('He so Coeffient la: ', model.coef_)
print('Do chinh xac cua mo hinh la: ', model.score(X,y))

range = np.arange(1.5,5.5,0.1)
X_range = pd.DataFrame([range, range**2, range**3, range**4, range**5, range**6, range**7, range**8, range**9, range**10]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'wt', y = 'mpg', figsize = (9,9), color = 'black', xlim = (0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# He so Intercept la:  -14921.11995188375
# He so Coeffient la:  [ 6.45813558e+04 -1.20086131e+05  1.26931928e+05 -8.46598454e+04
#   3.73155199e+04 -1.10334755e+04  2.16590404e+03 -2.70730544e+02
#   1.94974162e+01 -6.15515436e-01]
# Do chinh xac cua mo hinh la:  0.8702106571479111
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()

model.fit(X = data.loc[:,['wt','hp']],y = data['mpg'])
print('He so coeffient la: ',model.coef_)
print('He so intercept la: ',model.intercept_)
print('Do chinh xac cua mo hinh:',X,y)
# Out:
# He so coeffient la:  [-3.87783074 -0.03177295]
# He so intercept la:  37.227270116447215
# Do chinh xac cua mo hinh:        wt         wt          wt  ...             wt            wt            wt
# 0   2.620   6.864400   17.984728  ...    2220.293209  5.817168e+03  1.524098e+04
# 1   2.875   8.265625   23.763672  ...    4667.698460  1.341963e+04  3.858145e+04
# 2   2.320   5.382400   12.487168  ...     839.274212  1.947116e+03  4.517310e+03
# 3   3.215  10.336225   33.230963  ...   11414.261503  3.669685e+04  1.179804e+05
# 4   3.440  11.833600   40.707584  ...   19609.546071  6.745684e+04  2.320515e+05
# 5   3.460  11.971600   41.421736  ...   20540.394969  7.106977e+04  2.459014e+05
# 6   3.570  12.744900   45.499293  ...   26384.309263  9.419198e+04  3.362654e+05
# 7   3.190  10.176100   32.461759  ...   10723.226131  3.420709e+04  1.091206e+05
# 8   3.150   9.922500   31.255875  ...    9693.585167  3.053479e+04  9.618460e+04
# 9   3.440  11.833600   40.707584  ...   19609.546071  6.745684e+04  2.320515e+05
# 10  3.440  11.833600   40.707584  ...   19609.546071  6.745684e+04  2.320515e+05
# 11  4.070  16.564900   67.419143  ...   75293.116528  3.064430e+05  1.247223e+06
# 12  3.730  13.912900   51.895117  ...   37468.875072  1.397589e+05  5.213007e+05
# 13  3.780  14.288400   54.010152  ...   41680.641903  1.575528e+05  5.955497e+05
# 14  5.250  27.562500  144.703125  ...  577131.032730  3.029938e+06  1.590717e+07
# 15  5.424  29.419776  159.572865  ...  749130.444169  4.063284e+06  2.203925e+07
# 16  5.345  28.569025  152.701439  ...  666164.792976  3.560651e+06  1.903168e+07
# 17  2.200   4.840000   10.648000  ...     548.758735  1.207269e+03  2.655992e+03
# 18  1.615   2.608225    4.212283  ...      46.278600  7.473994e+01  1.207050e+02
# 19  1.835   3.367225    6.178858  ...     128.554874  2.358982e+02  4.328732e+02
# 20  2.465   6.076225   14.977895  ...    1363.124077  3.360101e+03  8.282649e+03
# 21  3.520  12.390400   43.614208  ...   23569.008218  8.296291e+04  2.920294e+05
# 22  3.435  11.799225   40.530338  ...   19382.684703  6.657952e+04  2.287007e+05
# 23  3.840  14.745600   56.623104  ...   47276.987448  1.815436e+05  6.971275e+05
# 24  3.845  14.784025   56.844576  ...   47771.706245  1.836822e+05  7.062581e+05
# 25  1.935   3.744225    7.245075  ...     196.538553  3.803021e+02  7.358846e+02
# 26  2.140   4.579600    9.800344  ...     439.855662  9.412911e+02  2.014363e+03
# 27  1.513   2.289169    3.463513  ...      27.460689  4.154802e+01  6.286216e+01
# 28  3.170  10.048900   31.855013  ...   10197.039409  3.232461e+04  1.024690e+05
# 29  2.770   7.672900   21.253933  ...    3466.076569  9.601032e+03  2.659486e+04
# 30  3.570  12.744900   45.499293  ...   26384.309263  9.419198e+04  3.362654e+05
# 31  2.780   7.728400   21.484952  ...    3567.453881  9.917522e+03  2.757071e+04
#
# [32 rows x 10 columns] 0     21.0
# 1     21.0
# 2     22.8
# 3     21.4
# 4     18.7
# 5     18.1
# 6     14.3
# 7     24.4
# 8     22.8
# 9     19.2
# 10    17.8
# 11    16.4
# 12    17.3
# 13    15.2
# 14    10.4
# 15    10.4
# 16    14.7
# 17    32.4
# 18    30.4
# 19    33.9
# 20    21.5
# 21    15.5
# 22    15.2
# 23    13.3
# 24    19.2
# 25    27.3
# 26    26.0
# 27    30.4
# 28    15.8
# 29    19.7
# 30    15.0
# 31    21.4
# Name: mpg, dtype: float64

# %%
import numpy as np
import pandas as pd
url = 'https://raw.githubusercontent.com/htphuc2110/File-/main/Advertising.csv'
data = pd.read_csv(url)
data.head(10)
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9
# 5           6    8.7   48.9       75.0    7.2
# 6           7   57.5   32.8       23.5   11.8
# 7           8  120.2   19.6       11.6   13.2
# 8           9    8.6    2.1        1.0    4.8
# 9          10  199.8    2.6       21.2   10.6

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data.hist()
plt.show()

# %%
correlation = data.corr()
print(correlation)

sns.pairplot(data)
# Out:
#             Unnamed: 0        TV     radio  newspaper     sales
# Unnamed: 0    1.000000  0.017715 -0.110680  -0.154944 -0.051616
# TV            0.017715  1.000000  0.054809   0.056648  0.782224
# radio        -0.110680  0.054809  1.000000   0.354104  0.576223
# newspaper    -0.154944  0.056648  0.354104   1.000000  0.228299
# sales        -0.051616  0.782224  0.576223   0.228299  1.000000

# %%
sns.heatmap(correlation,annot=True)
# Out:
# <Axes: >

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()

model.fit(X = pd.DataFrame(data['TV']), y = data['sales'])
print('Gia tri Intercept la: ', model.intercept_)
print('Gia tri Coeffient la: ', model.coef_)
model.score(X = pd.DataFrame(data['TV']), y = data['sales'])

data.plot(kind = 'scatter', x = 'TV', y = 'sales', figsize = (9,9), color = 'black')
y_pred = model.predict(X = pd.DataFrame(data['TV']))
plt.plot(data['TV'], y_pred,color='blue')
# Out:
# Gia tri Intercept la:  7.032593549127695
# Gia tri Coeffient la:  [0.04753664]
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['TV'],data['TV']**2,data['TV']**3]).T

y = data['sales']

model.fit(X,y = data['sales'])
print('He so Intercept la: ', model.intercept_)
print('He so Coeffient la: ', model.coef_)
print('Do chinh xac cua mo hinh la: ', model.score(X,y))

range = np.arange(0,500,1)
X_range = pd.DataFrame([range, range**2, range**3]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'TV', y = 'sales', figsize = (9,9), color = 'black', xlim = (0.7))
plt.plot(range,y_pred,color='blue')
# Out:
# He so Intercept la:  5.420106548191448
# He so Coeffient la:  [ 9.64341770e-02 -3.15222433e-04  5.57199796e-07]
# Do chinh xac cua mo hinh la:  0.6220016830036417
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()

model.fit(X = data.loc[:,['TV','radio']],y = data['sales'])
print('He so coeffient la: ',model.coef_)
print('He so intercept la: ',model.intercept_)
print('Do chinh xac cua mo hinh:',model.score(data.loc[:,['TV','radio']],y = data['sales']))
# Out:
# He so coeffient la:  [0.04575482 0.18799423]
# He so intercept la:  2.9210999124051362
# Do chinh xac cua mo hinh: 0.8971942610828957
