# %%
pip install scikit-fuzzy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 994.0/994.0 KB 25.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for scikit-fuzzy: filename=scikit_fuzzy-0.4.2-py3-none-any.whl size=894088 sha256=b7b83a3006be0421a1ebfc5f3a416f3fa1a5e41fe9d1de9f9e4267e55620aa31
#   Stored in directory: /root/.cache/pip/wheels/2c/04/80/7eefb1a2de7d36aefd06432fab2a1486caf0a0596a7067391a
# Successfully built scikit-fuzzy
# ...

# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl 

fever = ctrl.Antecedent(np.arange(0,1.1,0.1),'fever')
headache = ctrl.Antecedent(np.arange(0,1.1,0.1),'headache')
nausea = ctrl.Antecedent(np.arange(0,1.1,0.1),'nausea')
vomiting = ctrl.Antecedent(np.arange(0,1.1,0.1),'vomiting')
jaundice = ctrl.Antecedent(np.arange(0,1.1,0.1),'jaundice')
enlarge_liver = ctrl.Antecedent(np.arange(0,1.1,0.1),'enlarge_liver')
joint_pain = ctrl.Antecedent(np.arange(0,1.1,0.1),'joint_pain')
body_weakness = ctrl.Antecedent(np.arange(0,1.1,0.1),'body_weakness')
dizziness = ctrl.Antecedent(np.arange(0,1.1,0.1),'dizziness')
loss_of_appetite = ctrl.Antecedent(np.arange(0,1.1,0.1),'loss_of_appetite')
MP = ctrl.Antecedent(np.arange(0,1.1,0.1),'MP')
conclusion = ctrl.Consequent(np.arange(0,1.1,0.1),'conclusion')

fever['minor'] = fuzz.trimf(fever.universe,[0.1,0.1,0.3])
fever['moderate'] = fuzz.trimf(fever.universe,[0.2,0.45,0.6])
fever['severe'] = fuzz.trimf(fever.universe,[0.5,0.7,0.8])
fever['very_severe'] = fuzz.trimf(fever.universe,[0.7,1,1])

headache['minor'] = fuzz.trimf(headache.universe,[0.1,0.1,0.3])
headache['moderate'] = fuzz.trimf(headache.universe,[0.2,0.45,0.6])
headache['severe'] = fuzz.trimf(headache.universe,[0.5,0.7,0.8])
headache['very_severe'] = fuzz.trimf(headache.universe,[0.7,1,1])

nausea['minor'] = fuzz.trimf(nausea.universe,[0.1,0.1,0.3])
nausea['moderate'] = fuzz.trimf(nausea.universe,[0.2,0.45,0.6])
nausea['severe'] = fuzz.trimf(nausea.universe,[0.5,0.7,0.8])
nausea['very_severe'] = fuzz.trimf(nausea.universe,[0.7,1,1])

vomiting['minor'] = fuzz.trimf(vomiting.universe,[0.1,0.1,0.3])
vomiting['moderate'] = fuzz.trimf(vomiting.universe,[0.2,0.45,0.6])
vomiting['severe'] = fuzz.trimf(vomiting.universe,[0.5,0.7,0.8])
vomiting['very_severe'] = fuzz.trimf(vomiting.universe,[0.7,1,1])

jaundice['minor'] = fuzz.trimf(jaundice.universe,[0.1,0.1,0.3])
jaundice['moderate'] = fuzz.trimf(jaundice.universe,[0.2,0.45,0.6])
jaundice['severe'] = fuzz.trimf(jaundice.universe,[0.5,0.7,0.8])
jaundice['very_severe'] = fuzz.trimf(jaundice.universe,[0.7,1,1])

enlarge_liver['minor'] = fuzz.trimf(enlarge_liver.universe,[0.1,0.1,0.3])
enlarge_liver['moderate'] = fuzz.trimf(enlarge_liver.universe,[0.2,0.45,0.6])
enlarge_liver['severe'] = fuzz.trimf(enlarge_liver.universe,[0.5,0.7,0.8])
enlarge_liver['very_severe'] = fuzz.trimf(enlarge_liver.universe,[0.7,1,1])

joint_pain['minor'] = fuzz.trimf(joint_pain.universe,[0.1,0.1,0.3])
joint_pain['moderate'] = fuzz.trimf(joint_pain.universe,[0.2,0.45,0.6])
joint_pain['severe'] = fuzz.trimf(joint_pain.universe,[0.5,0.7,0.8])
joint_pain['very_severe'] = fuzz.trimf(joint_pain.universe,[0.7,1,1])

body_weakness['minor'] = fuzz.trimf(body_weakness.universe,[0.1,0.1,0.3])
body_weakness['moderate'] = fuzz.trimf(body_weakness.universe,[0.2,0.45,0.6])
body_weakness['severe'] = fuzz.trimf(body_weakness.universe,[0.5,0.7,0.8])
body_weakness['very_severe'] = fuzz.trimf(body_weakness.universe,[0.7,1,1])

dizziness['minor'] = fuzz.trimf(dizziness.universe,[0.1,0.1,0.3])
dizziness['moderate'] = fuzz.trimf(dizziness.universe,[0.2,0.45,0.6])
dizziness['severe'] = fuzz.trimf(dizziness.universe,[0.5,0.7,0.8])
dizziness['very_severe'] = fuzz.trimf(dizziness.universe,[0.7,1,1])

loss_of_appetite['minor'] = fuzz.trimf(loss_of_appetite.universe,[0.1,0.1,0.3])
loss_of_appetite['moderate'] = fuzz.trimf(loss_of_appetite.universe,[0.2,0.45,0.6])
loss_of_appetite['severe'] = fuzz.trimf(loss_of_appetite.universe,[0.5,0.7,0.8])
loss_of_appetite['very_severe'] = fuzz.trimf(loss_of_appetite.universe,[0.7,1,1])

MP['minor'] = fuzz.trimf(MP.universe,[0.1,0.1,0.3])
MP['moderate'] = fuzz.trimf(MP.universe,[0.2,0.45,0.6])
MP['severe'] = fuzz.trimf(MP.universe,[0.5,0.7,0.8])
MP['very_severe'] = fuzz.trimf(MP.universe,[0.7,1,1])

conclusion['minor'] = fuzz.trimf(conclusion.universe,[0.1,0.1,0.3])
conclusion['moderate'] = fuzz.trimf(conclusion.universe,[0.2,0.45,0.6])
conclusion['severe'] = fuzz.trimf(conclusion.universe,[0.5,0.7,0.8])
conclusion['very_severe'] = fuzz.trimf(conclusion.universe,[0.7,1,1])
                          
fever.view()
headache.view()
nausea.view()
vomiting.view()
jaundice.view()
enlarge_liver.view()
joint_pain.view()
body_weakness.view()
dizziness.view()
loss_of_appetite.view()
MP.view()
conclusion.view()

rule1 = ctrl.Rule(fever['minor'] & headache['minor'] & nausea['minor'] 
                   & vomiting['minor'] & jaundice['minor'] & enlarge_liver['minor'] 
                   & joint_pain['minor'] & body_weakness['minor'] & dizziness['severe'] 
                   & loss_of_appetite['minor'] & MP['minor'], conclusion['minor'])
rule2 = ctrl.Rule(fever['moderate'] & headache['minor'] & nausea['minor'] 
                   & vomiting['minor'] & jaundice['minor'] & enlarge_liver['minor'] 
                   & joint_pain['moderate'] & body_weakness['moderate'] & dizziness['severe'] 
                   & loss_of_appetite['severe'] & MP['moderate'], conclusion['moderate'])
rule3 = ctrl.Rule(fever['severe'] & headache['moderate'] & nausea['minor'] 
                   & vomiting['minor'] & jaundice['minor'] & enlarge_liver['minor'] 
                   & joint_pain['minor'] & body_weakness['severe'] & dizziness['severe'] 
                   & loss_of_appetite['severe'] & MP['moderate'], conclusion['severe'])
rule4 = ctrl.Rule(fever['very_severe'] & headache['minor'] & nausea['minor'] 
                   & vomiting['minor'] & jaundice['minor'] & enlarge_liver['minor'] 
                   & joint_pain['severe'] & body_weakness['severe'] & dizziness['minor'] 
                   & loss_of_appetite['minor'] & MP['severe'], conclusion['very_severe'])
rule5 = ctrl.Rule(fever['moderate'] & headache['minor'] & nausea['minor'] 
                   & vomiting['moderate'] & jaundice['minor'] & enlarge_liver['minor'] 
                   & joint_pain['moderate'] & body_weakness['moderate'] & dizziness['moderate'] 
                   & loss_of_appetite['severe'] & MP['moderate'], conclusion['moderate'])
rule6 = ctrl.Rule(fever['minor'] & headache['moderate'] & nausea['moderate'] 
                   & vomiting['minor'] & jaundice['minor'] & enlarge_liver['minor'] 
                   & joint_pain['minor'] & body_weakness['minor'] & dizziness['moderate'] 
                   & loss_of_appetite['minor'] & MP['minor'], conclusion['minor'])
rule7 = ctrl.Rule(fever['minor'] & headache['minor'] & nausea['moderate'] 
                   & vomiting['moderate'] & jaundice['minor'] & enlarge_liver['minor'] 
                   & joint_pain['severe'] & body_weakness['severe'] & dizziness['moderate'] 
                   & loss_of_appetite['moderate'] & MP['moderate'], conclusion['severe'])
rule8 = ctrl.Rule(fever['moderate'] & headache['moderate'] & nausea['moderate'] 
                   & vomiting['moderate'] & jaundice['moderate'] & enlarge_liver['moderate'] 
                   & joint_pain['moderate'] & body_weakness['moderate'] & dizziness['moderate'] 
                   & loss_of_appetite['moderate'] & MP['moderate'], conclusion['moderate'])
rule9 = ctrl.Rule(fever['moderate'] & headache['minor'] & nausea['moderate'] 
                   & vomiting['moderate'] & jaundice['minor'] & enlarge_liver['severe'] 
                   & joint_pain['moderate'] & body_weakness['moderate'] & dizziness['severe'] 
                   & loss_of_appetite['moderate'] & MP['moderate'], conclusion['moderate'])
rule10 = ctrl.Rule(fever['minor'] & headache['minor'] & nausea['moderate'] 
                   & vomiting['moderate'] & jaundice['minor'] & enlarge_liver['moderate'] 
                   & joint_pain['minor'] & body_weakness['minor'] & dizziness['minor'] 
                   & loss_of_appetite['minor'] & MP['minor'], conclusion['minor'])
rule11 = ctrl.Rule(fever['severe'] & headache['severe'] & nausea['severe'] 
                   & vomiting['severe'] & jaundice['severe'] & enlarge_liver['severe'] 
                   & joint_pain['severe'] & body_weakness['very_severe'] & dizziness['severe'] 
                   & loss_of_appetite['severe'] & MP['moderate'], conclusion['very_severe'])
rule12 = ctrl.Rule(fever['moderate'] & headache['severe'] & nausea['moderate'] 
                   & vomiting['severe'] & jaundice['moderate'] & enlarge_liver['severe'] 
                   & joint_pain['moderate'] & body_weakness['severe'] & dizziness['moderate'] 
                   & loss_of_appetite['minor'] & MP['moderate'], conclusion['severe'])
rule13 = ctrl.Rule(fever['minor'] & headache['moderate'] & nausea['moderate'] 
                   & vomiting['moderate'] & jaundice['minor'] & enlarge_liver['minor'] 
                   & joint_pain['minor'] & body_weakness['moderate'] & dizziness['minor'] 
                   & loss_of_appetite['moderate'] & MP['moderate'], conclusion['moderate'])
rule14 = ctrl.Rule(fever['severe'] & headache['severe'] & nausea['moderate'] 
                   & vomiting['severe'] & jaundice['severe'] & enlarge_liver['severe'] 
                   & joint_pain['severe'] & body_weakness['severe'] & dizziness['moderate'] 
                   & loss_of_appetite['moderate'] & MP['severe'], conclusion['severe'])
rule15 = ctrl.Rule(fever['minor'] & headache['minor'] & nausea['minor'] 
                   & vomiting['moderate'] & jaundice['minor'] & enlarge_liver['minor'] 
                   & joint_pain['minor'] & body_weakness['severe'] & dizziness['minor'] 
                   & loss_of_appetite['severe'] & MP['moderate'], conclusion['severe'])
rule16 = ctrl.Rule(fever['very_severe'] & headache['moderate'] & nausea['minor'] 
                   & vomiting['moderate'] & jaundice['severe'] & enlarge_liver['moderate'] 
                   & joint_pain['minor'] & body_weakness['very_severe'] & dizziness['severe'] 
                   & loss_of_appetite['minor'] & MP['moderate'], conclusion['very_severe'])
rule17 = ctrl.Rule(fever['minor'] & headache['very_severe'] & nausea['moderate'] 
                   & vomiting['moderate'] & jaundice['minor'] & enlarge_liver['moderate'] 
                   & joint_pain['minor'] & body_weakness['moderate'] & dizziness['very_severe'] 
                   & loss_of_appetite['minor'] & MP['moderate'], conclusion['very_severe'])
rule18 = ctrl.Rule(fever['moderate'] & headache['very_severe'] & nausea['very_severe'] 
                   & vomiting['minor'] & jaundice['severe'] & enlarge_liver['severe'] 
                   & joint_pain['moderate'] & body_weakness['severe'] & dizziness['very_severe'] 
                   & loss_of_appetite['very_severe'] & MP['severe'], conclusion['very_severe'])
rule19 = ctrl.Rule(fever['moderate'] & headache['moderate'] & nausea['moderate'] 
                   & vomiting['moderate'] & jaundice['minor'] & enlarge_liver['minor'] 
                   & joint_pain['moderate'] & body_weakness['moderate'] & dizziness['moderate'] 
                   & loss_of_appetite['moderate'] & MP['moderate'], conclusion['moderate'])
rule20 = ctrl.Rule(fever['very_severe'] & headache['severe'] & nausea['severe'] 
                   & vomiting['severe'] & jaundice['severe'] & enlarge_liver['severe'] 
                   & joint_pain['severe'] & body_weakness['severe'] & dizziness['severe'] 
                   & loss_of_appetite['severe'] & MP['moderate'], conclusion['very_severe'])




conclusing_ctrl = ctrl.ControlSystem([rule1,rule2,rule3,rule4,rule5,rule6,rule7,rule8,rule9,rule10,rule11,rule12,rule13,rule14,rule15,rule16,rule17,rule18,rule19,rule20])
conclusing = ctrl.ControlSystemSimulation(conclusing_ctrl)


conclusing.input['fever'] = 0.25
conclusing.input['headache'] = 0.25
conclusing.input['nausea'] = 0.25
conclusing.input['vomiting'] = 0.25
conclusing.input['jaundice'] = 0.25
conclusing.input['enlarge_liver'] = 0.25
conclusing.input['joint_pain'] = 0.25
conclusing.input['body_weakness'] = 0.25
conclusing.input['dizziness'] = 0.7
conclusing.input['loss_of_appetite'] = 0.25
conclusing.input['MP'] = 0.25

conclusing.compute()
print(conclusing.output['conclusion'])
conclusion.view(sim = conclusing)
# Out:
# 0.1440476190476191
